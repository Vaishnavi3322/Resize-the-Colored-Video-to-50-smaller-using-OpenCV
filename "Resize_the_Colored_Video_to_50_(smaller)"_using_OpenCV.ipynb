# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi3322/Resize-the-Colored-Video-to-50-smaller-using-OpenCV/blob/main/%22Resize_the_Colored_Video_to_50_(smaller)%22_using_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ----
# ## **"Resizing Colored Video to Grey Scale (b/w)" using OpenCV**
# ----

# %% [markdown]
# ----
# #### **Installing Important Libraries**
# ----

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ----
# #### **Importing Important Libraries**
# ----

# %%
from pytube import YouTube

# %% [markdown]
# ----
# #### **Defining Download Video Function**
# ----

# %%
def download_video(url, output_path):
    try:
        # Create a YouTube object
        youtube = YouTube(url)

        # Get the highest resolution video stream
        video = youtube.streams.get_highest_resolution()

        # Download the video to the specified output path
        video.download(output_path=output_path)

        print("Video downloaded successfully!")
    except Exception as e:
        print(f"Error: {str(e)}")

# %% [markdown]
# ----
# #### **Downloading Video**
# ----

# %%
video_url = "https://www.youtube.com/watch?v=KkpIrGX2SC0"
output_path = "./content/"

download_video(video_url, output_path)
# Out:
# Video downloaded successfully!

# %%
import cv2

# Open the video file
video_path = "/content/content/Naari Ek Mystery - The Secrets Of Womens Voice  Stand Up Comedy ft Vishal Tyagi.mp4"  # Replace with the actual video file path
video = cv2.VideoCapture(video_path)

# Get the video properties
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

# Create a VideoWriter object to save the grayscale video
output_path = "/content/file.mp4"  # Replace with the desired output file path
output = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height), isColor=False)

# Process each frame of the video
frame_count = 0
while video.isOpened():
    ret, frame = video.read()
    if not ret:
        break
    # Get the original dimensions of the image
        height, width = img.shape[:2]

            # Calculate the new dimensions for 50% smaller size
        new_width = int(width * 0.5)
        new_height = int(height * 0.5)

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Write the grayscale frame to the output video
    output.write(gray_frame)

    # Display the progress
    frame_count += 1
    print(f"Processing frame {frame_count}/{total_frames}")

# Release the video capture and writer objects
video.release()
output.release()

print("Resizing of video completed.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing frame 16502/21500
# Processing frame 16503/21500
# Processing frame 16504/21500
# Processing frame 16505/21500
# Processing frame 16506/21500
# Processing frame 16507/21500
# Processing frame 16508/21500
# Processing frame 16509/21500
# Processing frame 16510/21500
# Processing frame 16511/21500
# Processing frame 16512/21500
# Processing frame 16513/21500
# Processing frame 16514/21500
# Processing frame 16515/21500
# Processing frame 16516/21500
# Processing frame 16517/21500
# Processing frame 16518/21500
# Processing frame 16519/21500
# Processing frame 16520/21500
# Processing frame 16521/21500
# Processing frame 16522/21500
# Processing frame 16523/21500
# Processing frame 16524/21500
# Processing frame 16525/21500
# Processing frame 16526/21500
# Processing frame 16527/21500
# Processing frame 16528/21500
# Processing frame 16529/21500
# Processing frame 16530/21500
# Processing frame 16531/21500
# ...
